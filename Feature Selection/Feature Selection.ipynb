# %% [markdown]
# # FEATURE SELECTION

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("breast-cancer-data.csv")
pd.set_option('display.max_columns', None)
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  \
# 0         0.2419                 0.07871     1.0950      0.9053         8.589
# 1         0.1812                 0.05667     0.5435      0.7339         3.398
# 2         0.2069                 0.05999     0.7456      0.7869         4.585
# 3         0.2597                 0.09744     0.4956      1.1560         3.445
# 4         0.1809                 0.05883     0.7572      0.7813         5.438
#
#    area_se  smoothness_se  compactness_se  concavity_se  concave points_se  \
# 0   153.40       0.006399         0.04904       0.05373            0.01587
# 1    74.08       0.005225         0.01308       0.01860            0.01340
# 2    94.03       0.006150         0.04006       0.03832            0.02058
# 3    27.23       0.009110         0.07458       0.05661            0.01867
# 4    94.44       0.011490         0.02461       0.05688            0.01885
#
#    symmetry_se  fractal_dimension_se  radius_worst  texture_worst  \
# 0      0.03003              0.006193         25.38          17.33
# 1      0.01389              0.003532         24.99          23.41
# 2      0.02250              0.004571         23.57          25.53
# 3      0.05963              0.009208         14.91          26.50
# 4      0.01756              0.005115         22.54          16.67
#
#    perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0           184.60      2019.0            0.1622             0.6656
# 1           158.80      1956.0            0.1238             0.1866
# 2           152.50      1709.0            0.1444             0.4245
# 3            98.87       567.7            0.2098             0.8663
# 4           152.20      1575.0            0.1374             0.2050
#
#    concavity_worst  concave points_worst  symmetry_worst  \
# 0           0.7119                0.2654          0.4601
# 1           0.2416                0.1860          0.2750
# 2           0.4504                0.2430          0.3613
# 3           0.6869                0.2575          0.6638
# 4           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst
# 0                  0.11890
# 1                  0.08902
# 2                  0.08758
# 3                  0.17300
# 4                  0.07678

# %% [markdown]
# ### shape function

# %%
df.shape
# Out:
# (569, 32)

# %% [markdown]
# ### info function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 142.4+ KB

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
#defining the array as np.array
feature_names = np.array(['radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst'])

# %%
#convert diagnosis column to 1/0 and store in new column target
from sklearn.preprocessing import LabelEncoder

# %%
#Encode label diagnosis
#M -> 1
#B -> 0

#Converting diagnossi to numerical variable in df
df['diagnosis'] = df['diagnosis'].map({'M':1,'B':0}).astype(int)

# %%
df['diagnosis'].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
#install factor analyzer
# !pip install factor_analyzer
# Out:
# Requirement already satisfied: factor_analyzer in c:\users\pc\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: pre-commit in c:\users\pc\anaconda3\lib\site-packages (from factor_analyzer) (2.20.0)
# Requirement already satisfied: numpy in c:\users\pc\anaconda3\lib\site-packages (from factor_analyzer) (1.20.1)
# Requirement already satisfied: scikit-learn in c:\users\pc\anaconda3\lib\site-packages (from factor_analyzer) (1.1.1)
# Requirement already satisfied: pandas in c:\users\pc\anaconda3\lib\site-packages (from factor_analyzer) (1.2.4)
# Requirement already satisfied: scipy in c:\users\pc\anaconda3\lib\site-packages (from factor_analyzer) (1.6.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\pc\anaconda3\lib\site-packages (from pandas->factor_analyzer) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\pc\anaconda3\lib\site-packages (from pandas->factor_analyzer) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\pc\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->factor_analyzer) (1.15.0)
# Requirement already satisfied: virtualenv>=20.0.8 in c:\users\pc\anaconda3\lib\site-packages (from pre-commit->factor_analyzer) (20.16.6)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\pc\anaconda3\lib\site-packages (from pre-commit->factor_analyzer) (5.4.1)
# Requirement already satisfied: cfgv>=2.0.0 in c:\users\pc\anaconda3\lib\site-packages (from pre-commit->factor_analyzer) (3.3.1)
# Requirement already satisfied: identify>=1.0.0 in c:\users\pc\anaconda3\lib\site-packages (from pre-commit->factor_analyzer) (2.5.8)
# Requirement already satisfied: nodeenv>=0.11.1 in c:\users\pc\anaconda3\lib\site-packages (from pre-commit->factor_analyzer) (1.7.0)
# Requirement already satisfied: toml in c:\users\pc\anaconda3\lib\site-packages (from pre-commit->factor_analyzer) (0.10.2)
# Requirement already satisfied: setuptools in c:\users\pc\anaconda3\lib\site-packages (from nodeenv>=0.11.1->pre-commit->factor_analyzer) (52.0.0.post20210125)
# Requirement already satisfied: filelock<4,>=3.4.1 in c:\users\pc\anaconda3\lib\site-packages (from virtualenv>=20.0.8->pre-commit->factor_analyzer) (3.8.0)
# Requirement already satisfied: platformdirs<3,>=2.4 in c:\users\pc\anaconda3\lib\site-packages (from virtualenv>=20.0.8->pre-commit->factor_analyzer) (2.5.2)
# Requirement already satisfied: distlib<1,>=0.3.6 in c:\users\pc\anaconda3\lib\site-packages (from virtualenv>=20.0.8->pre-commit->factor_analyzer) (0.3.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\pc\anaconda3\lib\site-packages (from scikit-learn->factor_analyzer) (2.1.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\pc\anaconda3\lib\site-packages (from scikit-learn->factor_analyzer) (1.0.1)

# %% [markdown]
# ### Bartlett's Test

# %%
from factor_analyzer import FactorAnalyzer
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
chi_square_value, p_value = calculate_bartlett_sphericity(df)
chi_square_value, p_value
# Out:
# (40196.161163007855, 0.0)

# %% [markdown]
# ### Kaiser-Meyer-Olkin Test

# %%
from factor_analyzer.factor_analyzer import calculate_kmo
kmo_all,kmo_model = calculate_kmo(df)
kmo_model
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\factor_analyzer\utils.py:244: UserWarning: The inverse of the variance-covariance matrix was calculated using the Moore-Penrose generalized matrix inversion, due to its determinant being at or very close to zero.
#   warnings.warn(
# 0.2606290621756102

# %%
df.head(2)
# Out:
#        id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  842302          1        17.99         10.38           122.8     1001.0
# 1  842517          1        20.57         17.77           132.9     1326.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
#
#    symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  \
# 0         0.2419                 0.07871     1.0950      0.9053         8.589
# 1         0.1812                 0.05667     0.5435      0.7339         3.398
#
#    area_se  smoothness_se  compactness_se  concavity_se  concave points_se  \
# 0   153.40       0.006399         0.04904       0.05373            0.01587
# 1    74.08       0.005225         0.01308       0.01860            0.01340
#
#    symmetry_se  fractal_dimension_se  radius_worst  texture_worst  \
# 0      0.03003              0.006193         25.38          17.33
# 1      0.01389              0.003532         24.99          23.41
#
#    perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0            184.6      2019.0            0.1622             0.6656
# 1            158.8      1956.0            0.1238             0.1866
#
#    concavity_worst  concave points_worst  symmetry_worst  \
# 0           0.7119                0.2654          0.4601
# 1           0.2416                0.1860          0.2750
#
#    fractal_dimension_worst
# 0                  0.11890
# 1                  0.08902

# %% [markdown]
# ### Finding significant Variables

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_1c221_row0_col0,#T_1c221_row1_col1,#T_1c221_row2_col2,#T_1c221_row2_col4,#T_1c221_row3_col3,#T_1c221_row4_col2,#T_1c221_row4_col4,#T_1c221_row5_col5,#T_1c221_row6_col6,#T_1c221_row7_col7,#T_1c221_row8_col8,#T_1c221_row9_col9,#T_1c221_row10_col10,#T_1c221_row11_col11,#T_1c221_row12_col12,#T_1c221_row13_col13,#T_1c221_row14_col14,#T_1c221_row15_col15,#T_1c221_row16_col16,#T_1c221_row17_col17,#T_1c221_row18_col18,#T_1c221_row19_col19,#T_1c221_row20_col20,#T_1c221_row21_col21,#T_1c221_row22_col22,#T_1c221_row23_col23,#T_1c221_row24_col24,#T_1c221_row25_col25,#T_1c221_row26_col26,#T_1c221_row27_col27,#T_1c221_row28_col28,#T_1c221_row29_col29,#T_1c221_row30_col30,#T_1c221_row31_col31{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_1c221_row0_col1,#T_1c221_row0_col14,#T_1c221_row0_col20,#T_1c221_row20_col22,#T_1c221_row20_col25,#T_1c221_row20_col28,#T_1c221_row30_col16,#T_1c221_row31_col15{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_1c221_row0_col2,#T_1c221_row0_col5,#T_1c221_row6_col17,#T_1c221_row12_col18{
#             background-color:  #9dbdff;
#             color:  #000000;
#         }#T_1c221_row0_col3,#T_1c221_row3_col17,#T_1c221_row5_col18,#T_1c221_row13_col2,#T_1c221_row15_col21{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_1c221_row0_col4,#T_1c221_row11_col29,#T_1c221_row15_col6,#T_1c221_row18_col6,#T_1c221_row23_col8,#T_1c221_row23_col15,#T_1c221_row25_col26{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_1c221_row0_col6,#T_1c221_row11_col24,#T_1c221_row16_col28,#T_1c221_row23_col19,#T_1c221_row24_col16,#T_1c221_row30_col0{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_1c221_row0_col7,#T_1c221_row0_col8,#T_1c221_row0_col10,#T_1c221_row0_col17,#T_1c221_row0_col18,#T_1c221_row0_col19,#T_1c221_row2_col11,#T_1c221_row2_col21,#T_1c221_row3_col6,#T_1c221_row11_col0,#T_1c221_row11_col2,#T_1c221_row11_col3,#T_1c221_row11_col4,#T_1c221_row11_col5,#T_1c221_row11_col12,#T_1c221_row11_col14,#T_1c221_row11_col15,#T_1c221_row11_col22,#T_1c221_row11_col25,#T_1c221_row13_col9,#T_1c221_row13_col26,#T_1c221_row13_col27,#T_1c221_row13_col28,#T_1c221_row13_col29,#T_1c221_row13_col30,#T_1c221_row13_col31,#T_1c221_row16_col1,#T_1c221_row16_col23,#T_1c221_row16_col24,#T_1c221_row20_col23,#T_1c221_row22_col16,#T_1c221_row22_col20,#T_1c221_row30_col13{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_1c221_row0_col9,#T_1c221_row2_col20,#T_1c221_row4_col16,#T_1c221_row5_col11,#T_1c221_row5_col21,#T_1c221_row24_col13,#T_1c221_row24_col20,#T_1c221_row31_col0{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_1c221_row0_col11,#T_1c221_row5_col6,#T_1c221_row9_col20,#T_1c221_row12_col30,#T_1c221_row23_col11,#T_1c221_row26_col15{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_1c221_row0_col12,#T_1c221_row3_col26,#T_1c221_row5_col0,#T_1c221_row16_col0,#T_1c221_row16_col31,#T_1c221_row20_col4,#T_1c221_row25_col18,#T_1c221_row26_col3,#T_1c221_row26_col12,#T_1c221_row27_col16{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_1c221_row0_col13,#T_1c221_row1_col13,#T_1c221_row1_col20{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_1c221_row0_col15,#T_1c221_row0_col24,#T_1c221_row31_col2{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_1c221_row0_col16,#T_1c221_row0_col22,#T_1c221_row1_col17,#T_1c221_row3_col8,#T_1c221_row6_col14,#T_1c221_row8_col16,#T_1c221_row14_col11,#T_1c221_row19_col26,#T_1c221_row20_col18{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_1c221_row0_col21{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_1c221_row0_col23,#T_1c221_row9_col13{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_1c221_row0_col25,#T_1c221_row3_col12,#T_1c221_row14_col21,#T_1c221_row23_col9,#T_1c221_row31_col22,#T_1c221_row31_col23{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_1c221_row0_col26,#T_1c221_row0_col27,#T_1c221_row20_col3,#T_1c221_row20_col29,#T_1c221_row24_col11{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_1c221_row0_col28,#T_1c221_row1_col0,#T_1c221_row13_col6,#T_1c221_row29_col20{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_1c221_row0_col29,#T_1c221_row10_col3,#T_1c221_row13_col4,#T_1c221_row20_col27,#T_1c221_row22_col18,#T_1c221_row28_col16{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_1c221_row0_col30,#T_1c221_row16_col3,#T_1c221_row20_col9,#T_1c221_row21_col0{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_1c221_row0_col31,#T_1c221_row22_col13{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_1c221_row1_col2,#T_1c221_row1_col4,#T_1c221_row4_col29,#T_1c221_row18_col17,#T_1c221_row21_col17,#T_1c221_row24_col1,#T_1c221_row29_col25{
#             background-color:  #ee8669;
#             color:  #000000;
#         }#T_1c221_row1_col3,#T_1c221_row3_col13,#T_1c221_row14_col28,#T_1c221_row15_col7,#T_1c221_row19_col16,#T_1c221_row27_col18{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }#T_1c221_row1_col5,#T_1c221_row1_col9,#T_1c221_row2_col29,#T_1c221_row12_col22,#T_1c221_row12_col24,#T_1c221_row14_col24{
#             background-color:  #f29072;
#             color:  #000000;
#         }#T_1c221_row1_col6,#T_1c221_row2_col3,#T_1c221_row6_col4,#T_1c221_row6_col22,#T_1c221_row6_col24,#T_1c221_row10_col1,#T_1c221_row20_col17,#T_1c221_row26_col24,#T_1c221_row29_col11{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_1c221_row1_col7,#T_1c221_row7_col26,#T_1c221_row11_col6,#T_1c221_row12_col1,#T_1c221_row15_col8,#T_1c221_row26_col29{
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }#T_1c221_row1_col8,#T_1c221_row1_col28,#T_1c221_row4_col14,#T_1c221_row6_col11,#T_1c221_row15_col9,#T_1c221_row28_col1{
#             background-color:  #f7b396;
#             color:  #000000;
#         }#T_1c221_row1_col10,#T_1c221_row2_col23,#T_1c221_row3_col28,#T_1c221_row12_col27,#T_1c221_row15_col27,#T_1c221_row16_col6,#T_1c221_row17_col15,#T_1c221_row21_col10,#T_1c221_row29_col3{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_1c221_row1_col11,#T_1c221_row10_col13,#T_1c221_row15_col18,#T_1c221_row20_col7,#T_1c221_row21_col12,#T_1c221_row21_col26{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_1c221_row1_col12,#T_1c221_row6_col10,#T_1c221_row10_col6,#T_1c221_row24_col27,#T_1c221_row27_col4,#T_1c221_row29_col19{
#             background-color:  #edd2c3;
#             color:  #000000;
#         }#T_1c221_row1_col14,#T_1c221_row8_col31,#T_1c221_row11_col26,#T_1c221_row17_col29,#T_1c221_row19_col14,#T_1c221_row22_col7,#T_1c221_row29_col14{
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }#T_1c221_row1_col15,#T_1c221_row9_col19,#T_1c221_row14_col1,#T_1c221_row28_col30{
#             background-color:  #efcebd;
#             color:  #000000;
#         }#T_1c221_row1_col16,#T_1c221_row16_col7,#T_1c221_row20_col8,#T_1c221_row21_col1,#T_1c221_row22_col31{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_1c221_row1_col18,#T_1c221_row4_col26,#T_1c221_row9_col16{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_1c221_row1_col19,#T_1c221_row4_col19,#T_1c221_row6_col5,#T_1c221_row6_col25,#T_1c221_row10_col21,#T_1c221_row10_col24,#T_1c221_row17_col12,#T_1c221_row18_col10,#T_1c221_row26_col25,#T_1c221_row30_col4,#T_1c221_row30_col25{
#             background-color:  #b2ccfb;
#             color:  #000000;

# %% [markdown]
# ### Creating dataset of Significat variables

# %%
df_corr = df[['radius_mean','perimeter_mean','area_mean','radius_worst','perimeter_worst','area_worst','concave points_worst','diagnosis']]

# %%
kmo_all,kmo_model = calculate_kmo(df_corr)
kmo_model
# Out:
# 0.8033150436611332

# %% [markdown]
# ### Factor Analysis

# %%
from factor_analyzer import FactorAnalyzer
fa = FactorAnalyzer(rotation = 'varimax')
fa.fit(df_corr,11)
# Out:
# FactorAnalyzer(rotation='varimax', rotation_kwargs={})

# %%
ev,v = fa.get_eigenvalues()
ev
# Out:
# array([7.13692907e+00, 5.27776985e-01, 2.07156247e-01, 9.51692736e-02,
#        2.47054821e-02, 6.00670505e-03, 1.70185703e-03, 5.54376226e-04])

# %%
plt.scatter(range(1,df_corr.shape[1]+1),ev)
plt.plot(range(1,df_corr.shape[1]+1),ev)
plt.title('Scree Plot')
plt.xlabel('Factors')
plt.ylabel('Eigenvalues')
plt.grid()
plt.show()

# %%
fa1 = FactorAnalyzer(rotation = 'varimax',n_factors = 2)
fa1.fit(df,2)
# Out:
# FactorAnalyzer(n_factors=2, rotation='varimax', rotation_kwargs={})

# %%
fa1.loadings_
# Out:
# array([[ 0.09949821, -0.0175289 ],
#        [ 0.76990049,  0.2623415 ],
#        [ 0.97577565, -0.05180551],
#        [ 0.37374525,  0.08592885],
#        [ 0.97834605,  0.0038596 ],
#        [ 0.97757834, -0.04299327],
#        [ 0.21011043,  0.61739299],
#        [ 0.54025265,  0.78340654],
#        [ 0.71664403,  0.63252347],
#        [ 0.84801319,  0.44148548],
#        [ 0.19103234,  0.61468441],
#        [-0.26532101,  0.86590234],
#        [ 0.74312451,  0.18542383],
#        [-0.04891221,  0.18458444],
#        [ 0.7388625 ,  0.2275271 ],
#        [ 0.79163253,  0.08879413],
#        [-0.18452396,  0.38701832],
#        [ 0.22456327,  0.78529352],
#        [ 0.2181755 ,  0.66739594],
#        [ 0.3904135 ,  0.59545102],
#        [-0.08217262,  0.40098443],
#        [-0.03298699,  0.73180421],
#        [ 0.98993515, -0.00563542],
#        [ 0.36256059,  0.11401422],
#        [ 0.99041424,  0.05315551],
#        [ 0.97481138, -0.01017728],
#        [ 0.18911152,  0.5607166 ],
#        [ 0.46178052,  0.69523829],
#        [ 0.5755513 ,  0.64392356],
#        [ 0.7820377 ,  0.47681393],
#        [ 0.20855172,  0.49045165],
#        [ 0.06575214,  0.79707142]])

# %% [markdown]
# ### Confirmatory Factor Analysis

# %%
from factor_analyzer import ConfirmatoryFactorAnalyzer, ModelSpecificationParser
model_dict = {"F1": ['radius_mean','perimeter_mean','area_mean','radius_worst','perimeter_worst','diagnosis'],"F2": ['area_worst','concavity_mean','concave points_worst','concavity_worst','concave points_worst']}

model_spec = ModelSpecificationParser.parse_model_specification_from_dict(df_corr,model_dict)

cfa1 = ConfirmatoryFactorAnalyzer(model_spec, disp=False)
cfa1.fit(df_corr.values)

cfa1.loadings_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-b130f66608da> in <module>
#       5
#       6 cfa1 = ConfirmatoryFactorAnalyzer(model_spec, disp=False)
# ----> 7 cfa1.fit(df_corr.values)
#       8
#       9 cfa1.loadings_
#
# ~\anaconda3\lib\site-packages\factor_analyzer\confirmatory_factor_analyzer.py in fit(self, X, y)
#     740         # the constraints are set inside the objective function,
#     741         # so that we can avoid using linear programming methods (e.g. SLSQP)
# --> 742         res = minimize(
#     743             self._objective,
#     744             x0,
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     617                                   **options)
#     618     elif meth == 'l-bfgs-b':
# --> 619         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     620                                 callback=callback, **options)
#     621     elif meth == 'tnc':
#
# ~\anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     304             iprint = disp
#     305
# --> 306     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     307                                   bounds=new_bounds,
#     308                                   finite_diff_rel_step=finite_diff_rel_step)
#
# ~\anaconda3\lib\site-packages\scipy\optimize\optimize.py in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     259     # ScalarFunction caches. Reuse of fun(x) during grad
#     260     # calculation reduces overall function evaluations.
# --> 261     sf = ScalarFunction(fun, x0, args, grad, hess,
#     262                         finite_diff_rel_step, bounds, epsilon=epsilon)
#     263
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in __init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     134
#     135         self._update_fun_impl = update_fun
# --> 136         self._update_fun()
#     137
#     138         # Gradient evaluation
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in _update_fun(self)
#     224     def _update_fun(self):
#     225         if not self.f_updated:
# --> 226             self._update_fun_impl()
#     227             self.f_updated = True
#     228
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in update_fun()
#     131
#     132         def update_fun():
# --> 133             self.f = fun_wrapped(self.x)
#     134
#     135         self._update_fun_impl = update_fun
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_wrapped(x)
#     128         def fun_wrapped(x):
#     129             self.nfev += 1
# --> 130             return fun(x, *args)
#     131
#     132         def update_fun():
#
# ~\anaconda3\lib\site-packages\factor_analyzer\confirmatory_factor_analyzer.py in _objective(self, x0, cov_mtx, loadings)
#     613                 * (
#     614                     np.log(np.linalg.det(sigma_theta))
# --> 615                     + np.trace(cov_mtx.dot(np.linalg.inv(sigma_theta)))
#     616                 )
#     617             )
#
# ValueError: shapes (8,8) and (10,10) not aligned: 8 (dim 1) != 10 (dim 0)

# %%
cfa1.factor_varcovs_

# %%
cfa1.transform(df_corr.values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-1d383881bc42> in <module>
# ----> 1 cfa1.transform(df_corr.values)
#
# ~\anaconda3\lib\site-packages\factor_analyzer\confirmatory_factor_analyzer.py in transform(self, X)
#     844
#     845         # get the loadings and error variances
# --> 846         loadings = self.loadings_.copy()
#     847         error_vars = self.error_vars_.copy()
#     848
#
# AttributeError: 'NoneType' object has no attribute 'copy'

# %% [markdown]
# ## Use Case: Feature Selection in Cancer dataset Using PCA

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Import and Check the Data

# %%
df = pd.read_csv("breast-cancer-data.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  \
# 0         0.2419                 0.07871     1.0950      0.9053         8.589
# 1         0.1812                 0.05667     0.5435      0.7339         3.398
# 2         0.2069                 0.05999     0.7456      0.7869         4.585
# 3         0.2597                 0.09744     0.4956      1.1560         3.445
# 4         0.1809                 0.05883     0.7572      0.7813         5.438
#
#    area_se  smoothness_se  compactness_se  concavity_se  concave points_se  \
# 0   153.40       0.006399         0.04904       0.05373            0.01587
# 1    74.08       0.005225         0.01308       0.01860            0.01340
# 2    94.03       0.006150         0.04006       0.03832            0.02058
# 3    27.23       0.009110         0.07458       0.05661            0.01867
# 4    94.44       0.011490         0.02461       0.05688            0.01885
#
#    symmetry_se  fractal_dimension_se  radius_worst  texture_worst  \
# 0      0.03003              0.006193         25.38          17.33
# 1      0.01389              0.003532         24.99          23.41
# 2      0.02250              0.004571         23.57          25.53
# 3      0.05963              0.009208         14.91          26.50
# 4      0.01756              0.005115         22.54          16.67
#
#    perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0           184.60      2019.0            0.1622             0.6656
# 1           158.80      1956.0            0.1238             0.1866
# 2           152.50      1709.0            0.1444             0.4245
# 3            98.87       567.7            0.2098             0.8663
# 4           152.20      1575.0            0.1374             0.2050
#
#    concavity_worst  concave points_worst  symmetry_worst  \
# 0           0.7119                0.2654          0.4601
# 1           0.2416                0.1860          0.2750
# 2           0.4504                0.2430          0.3613
# 3           0.6869                0.2575          0.6638
# 4           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst
# 0                  0.11890
# 1                  0.08902
# 2                  0.08758
# 3                  0.17300
# 4                  0.07678

# %%
df.shape
# Out:
# (569, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 142.4+ KB

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
freature_names = np.array(['radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst'])

# %%
#convert dianoss column to 1/0 and store in new column target
from sklearn.preprocessing import LabelEncoder

# %%
#Encode label diagnosis
#M -> 1
#B -> 0

target_data = df['diagnosis']
encoder = LabelEncoder()
target_data = encoder.fit_transform(target_data)

# %%
df.drop(['diagnosis'],axis = 1, inplace =True)

# %% [markdown]
# ### Pricipal Component Analysis

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(df)
# Out:
# StandardScaler()

# %%
scales_data =scaler.transform(df)

# %%
#Two principal components
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
pca.fit(scales_data)
# Out:
# PCA(n_components=2)

# %%
x_pca = pca.transform(scales_data)

# %%
#shape of data
scales_data.shape
# Out:
# (569, 31)

# %%
x_pca.shape
# Out:
# (569, 2)

# %%
#Reduced 30 dimensons to just 2! Lets plot these two dimensions out!
plt.figure(figsize=(9,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=target_data,cmap = 'viridis')
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
# Out:
# Text(0, 0.5, 'Second Principal Component')

# %%
pca.components_
# Out:
# array([[ 0.02291216,  0.21891302,  0.10384388,  0.22753491,  0.22104577,
#          0.14241471,  0.2390673 ,  0.25828025,  0.26073811,  0.13797774,
#          0.06414779,  0.20611747,  0.01741339,  0.21144652,  0.20307642,
#          0.01467821,  0.1702884 ,  0.15354367,  0.18340675,  0.04241552,
#          0.10249607,  0.22800935,  0.10451545,  0.23663734,  0.22493214,
#          0.12782441,  0.20988456,  0.22860218,  0.2507462 ,  0.12267993,
#          0.13156024],
#        [-0.03406849, -0.2332714 , -0.0600442 , -0.214589  , -0.23066882,
#          0.18642221,  0.15245473,  0.06054163, -0.03416739,  0.19068498,
#          0.36653106, -0.1059357 ,  0.08954779, -0.08980704, -0.15277129,
#          0.20318988,  0.23250336,  0.19684608,  0.12996518,  0.18355863,
#          0.27958414, -0.21929604, -0.04550122, -0.19929599, -0.21898546,
#          0.17256296,  0.14425364,  0.09852652, -0.00753437,  0.14261944,
#          0.27570208]])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.42864701, 0.18376792])

# %%
#Three Principal Components
pca_3 = PCA(n_components=3)
pca_3.fit(scales_data)
x_pca_3 = pca_3.transform(scales_data)

# %%
x_pca_3.shape
# Out:
# (569, 3)

# %%
pca_3.explained_variance_ratio_
# Out:
# array([0.42864701, 0.18376792, 0.09146436])

# %% [markdown]
# ## Use Case: Feature Selection in Cancer dataset Using LDA

# %% [markdown]
# ### Import and Check the Data

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import KFold, cross_val_score, GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns

# %%
#Load data
df = pd.read_csv("breast-cancer-data.csv")
df.head(559)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.990         10.38          122.80     1001.0
# 1      842517         M       20.570         17.77          132.90     1326.0
# 2    84300903         M       19.690         21.25          130.00     1203.0
# 3    84348301         M       11.420         20.38           77.58      386.1
# 4    84358402         M       20.290         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 554    924632         B       12.880         28.92           82.50      514.3
# 555    924934         B       10.290         27.61           65.67      321.4
# 556    924964         B       10.160         19.59           64.73      311.7
# 557    925236         B        9.423         27.88           59.26      271.3
# 558    925277         B       14.590         22.68           96.39      657.1
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760        0.300100              0.14710
# 1            0.08474           0.07864        0.086900              0.07017
# 2            0.10960           0.15990        0.197400              0.12790
# 3            0.14250           0.28390        0.241400              0.10520
# 4            0.10030           0.13280        0.198000              0.10430
# ..               ...               ...             ...                  ...
# 554          0.08123           0.05824        0.061950              0.02343
# 555          0.09030           0.07658        0.059990              0.02738
# 556          0.10030           0.07504        0.005025              0.01116
# 557          0.08123           0.04971        0.000000              0.00000
# 558          0.08473           0.13300        0.102900              0.03736
#
#      symmetry_mean  fractal_dimension_mean  radius_se  texture_se  \
# 0           0.2419                 0.07871     1.0950      0.9053
# 1           0.1812                 0.05667     0.5435      0.7339
# 2           0.2069                 0.05999     0.7456      0.7869
# 3           0.2597                 0.09744     0.4956      1.1560
# 4           0.1809                 0.05883     0.7572      0.7813
# ..             ...                     ...        ...         ...
# 554         0.1566                 0.05708     0.2116      1.3600
# 555         0.1593                 0.06127     0.2199      2.2390
# 556         0.1791                 0.06331     0.2441      2.0900
# 557         0.1742                 0.06059     0.5375      2.9270
# 558         0.1454                 0.06147     0.2254      1.1080
#
#      perimeter_se  area_se  smoothness_se  compactness_se  concavity_se  \
# 0           8.589   153.40       0.006399         0.04904      0.053730
# 1           3.398    74.08       0.005225         0.01308      0.018600
# 2           4.585    94.03       0.006150         0.04006      0.038320
# 3           3.445    27.23       0.009110         0.07458      0.056610
# 4           5.438    94.44       0.011490         0.02461      0.056880
# ..            ...      ...            ...             ...           ...
# 554         1.502    16.83       0.008412         0.02153      0.038980
# 555         1.437    14.46       0.012050         0.02736      0.048040
# 556         1.648    16.80       0.012910         0.02222      0.004174
# 557         3.618    29.11       0.011590         0.01124      0.000000
# 558         2.224    19.54       0.004242         0.04639      0.065780
#
#      concave points_se  symmetry_se  fractal_dimension_se  radius_worst  \
# 0             0.015870      0.03003              0.006193         25.38
# 1             0.013400      0.01389              0.003532         24.99
# 2             0.020580      0.02250              0.004571         23.57
# 3             0.018670      0.05963              0.009208         14.91
# 4             0.018850      0.01756              0.005115         22.54
# ..                 ...          ...                   ...           ...
# 554           0.007620      0.01695              0.002801         13.89
# 555           0.017210      0.01843              0.004938         10.84
# 556           0.007082      0.02572              0.002278         10.65
# 557           0.000000      0.03004              0.003324         10.49
# 558           0.016060      0.01638              0.004406         15.48
#
#      texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0            17.33           184.60      2019.0            0.1622
# 1            23.41           158.80      1956.0            0.1238
# 2            25.53           152.50      1709.0            0.1444
# 3            26.50            98.87       567.7            0.2098
# 4            16.67           152.20      1575.0            0.1374
# ..             ...              ...         ...               ...
# 554          35.74            88.84       595.7            0.1227
# 555          34.91            69.57       357.6            0.1384
# 556          22.88            67.88       347.3            0.1265
# 557          34.24            66.50       330.6            0.1073
# 558          27.27           105.90       733.5            0.1026
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560          0.71190               0.26540          0.4601
# 1              0.18660          0.24160               0.18600          0.2750
# 2              0.42450          0.45040               0.24300          0.3613
# 3              0.86630          0.68690               0.25750          0.6638
# 4              0.20500          0.40000               0.16250          0.2364
# ..                 ...              ...                   ...             ...
# 554            0.16200          0.24390               0.06493          0.2372
# 555            0.17100          0.20000               0.09127          0.2226
# 556            0.12000          0.01005               0.02232          0.2262
# 557            0.07158          0.00000               0.00000          0.2475
# 558            0.31710          0.36620               0.11050          0.2258
#
#      fractal_dimension_worst
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 554                  0.07242
# 555                  0.08283
# 556                  0.06742
# 557                  0.06969
# 558                  0.08004
#
# [559 rows x 32 columns]

# %%
df.shape
# Out:
# (569, 32)

# %%
#map categorical variable 'diagnosis' into numeric
df.diagnosis = df.diagnosis.map({'M':1,'B':0})

# %%
#head will show the rows  and () default take 5 top rows as output.
df.head(5)
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  \
# 0         0.2419                 0.07871     1.0950      0.9053         8.589
# 1         0.1812                 0.05667     0.5435      0.7339         3.398
# 2         0.2069                 0.05999     0.7456      0.7869         4.585
# 3         0.2597                 0.09744     0.4956      1.1560         3.445
# 4         0.1809                 0.05883     0.7572      0.7813         5.438
#
#    area_se  smoothness_se  compactness_se  concavity_se  concave points_se  \
# 0   153.40       0.006399         0.04904       0.05373            0.01587
# 1    74.08       0.005225         0.01308       0.01860            0.01340
# 2    94.03       0.006150         0.04006       0.03832            0.02058
# 3    27.23       0.009110         0.07458       0.05661            0.01867
# 4    94.44       0.011490         0.02461       0.05688            0.01885
#
#    symmetry_se  fractal_dimension_se  radius_worst  texture_worst  \
# 0      0.03003              0.006193         25.38          17.33
# 1      0.01389              0.003532         24.99          23.41
# 2      0.02250              0.004571         23.57          25.53
# 3      0.05963              0.009208         14.91          26.50
# 4      0.01756              0.005115         22.54          16.67
#
#    perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0           184.60      2019.0            0.1622             0.6656
# 1           158.80      1956.0            0.1238             0.1866
# 2           152.50      1709.0            0.1444             0.4245
# 3            98.87       567.7            0.2098             0.8663
# 4           152.20      1575.0            0.1374             0.2050
#
#    concavity_worst  concave points_worst  symmetry_worst  \
# 0           0.7119                0.2654          0.4601
# 1           0.2416                0.1860          0.2750
# 2           0.4504                0.2430          0.3613
# 3           0.6869                0.2575          0.6638
# 4           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst
# 0                  0.11890
# 1                  0.08902
# 2                  0.08758
# 3                  0.17300
# 4                  0.07678

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
#drop redundant column 'id'
df.drop('id',axis=1, inplace=True)

# %%
#Check for na values
df.isnull().any()
# Out:
# diagnosis                  False
# radius_mean                False
# texture_mean               False
# perimeter_mean             False
# area_mean                  False
# smoothness_mean            False
# compactness_mean           False
# concavity_mean             False
# concave points_mean        False
# symmetry_mean              False
# fractal_dimension_mean     False
# radius_se                  False
# texture_se                 False
# perimeter_se               False
# area_se                    False
# smoothness_se              False
# compactness_se             False
# concavity_se               False
# concave points_se          False
# symmetry_se                False
# fractal_dimension_se       False
# radius_worst               False
# texture_worst              False
# perimeter_worst            False
# area_worst                 False
# smoothness_worst           False
# compactness_worst          False
# concavity_worst            False
# concave points_worst       False
# symmetry_worst             False
# fractal_dimension_worst    False
# dtype: bool

# %%
X_train,X_val,y_train,y_val = train_test_split(df.iloc[:,:-1], df['diagnosis'], train_size=0.8, test_size=0.2, random_state=120)

# %%
from sklearn.preprocessing import Normalizer

norm = Normalizer()
norm.fit(X_train)
X_train_norm = norm.transform(X_train)
X_val_norm = norm.transform(X_val)

# %% [markdown]
# ### LDA

# %%
lda = LinearDiscriminantAnalysis()
lda.fit(X_train_norm, y_train)
lda_predicted = lda.predict(X_val_norm)

print('LDA Accuracy is : {}'.format(accuracy_score(y_val,lda_predicted)))

print('LDA Classification Report')
print(classification_report(y_val,lda_predicted))
# Out:
# LDA Accuracy is : 1.0
# LDA Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        71
#            1       1.00      1.00      1.00        43
#
#     accuracy                           1.00       114
#    macro avg       1.00      1.00      1.00       114
# weighted avg       1.00      1.00      1.00       114

# %%
confusion_matrix_lda = pd.DataFrame(confusion_matrix(y_val,lda_predicted),
                                   index =['Actual Negative','Actual Positive'],
                                   columns = ['Predicted nagative','Predictive Positive'])
confusion_matrix_lda
# Out:
#                  Predicted nagative  Predictive Positive
# Actual Negative                  71                    0
# Actual Positive                   0                   43
